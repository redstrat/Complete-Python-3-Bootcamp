# %%
import requests

# %%
req = requests.get('https://en.wikipedia.org/wiki/Deep_Blue_versus_Garry_Kasparov')

# %%
type(req)
# Out:
# requests.models.Response

# %%
req.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Deep Blue versus Garry Kasparov - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-wid
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(req.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Deep Blue versus Garry Kasparov - Wikipedia</title>
# ...

# %%
b = soup.select('.mw-file-element')[0]

# %%
b
# Out:
# <img alt="" class="mw-file-element" data-file-height="601" data-file-width="400" decoding="async" height="240" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/160px-Deep_Blue.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/240px-Deep_Blue.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/320px-Deep_Blue.jpg 2x" width="160"/>

# %%
type(b[0])
# Out:
# bs4.element.Tag

# %%
b['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/160px-Deep_Blue.jpg'

# %% [markdown]
# <img
# src='//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/160px-Deep_Blue.jpg'>
